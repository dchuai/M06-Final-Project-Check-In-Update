# %%
# Group2:
# Team Members list:
# 1. Karima Kouadri Boudjelthia,
# 2. Micheal Mekoya,
# 3. Dim Huai

# M06 Final Project Check-In 

class SweetDelights:
    def __init__(self):
        self.users = []
        self.products = []
        self.orders = []

    def add_user(self, user):
        self.users.append(user)

    def add_product(self, product):
        self.products.append(product)

    def create_order(self, user, products):
        order = Order(user, products)
        self.orders.append(order)

    def generate_sales_report(self):
        total_revenue = sum(order.calculate_total() for order in self.orders)
        print(f"Total Revenue: ${total_revenue}")

    def show_inventory(self):
        for product in self.products:
            print(f"{product.name} - Quantity: {product.quantity}")

class User:
    def __init__(self, username, password):
        self.username = username
        self.password = password
        self.orders = []

    def view_order_history(self):
        if self.orders:
            print(f"Order History for {self.username}:")
            for order in self.orders:
                print(f"Order Status: {order.status}, Total Amount: ${order.calculate_total()}")
        else:
            print("No order history available.")

    def update_profile(self, new_password):
        self.password = new_password
        print(f"Profile updated for {self.username}.")

class Product:
    def __init__(self, name, price, quantity):
        self.name = name
        self.price = price
        self.quantity = quantity

    def update_product(self, new_price, new_quantity):
        self.price = new_price
        self.quantity = new_quantity
        print(f"{self.name} updated - Price: ${self.price}, Quantity: {self.quantity}")

class Order:
    def __init__(self, user, products):
        self.user = user
        self.products = products
        self.status = "Pending"

    def calculate_total(self):
        total = sum(product.price for product in self.products)
        return total

    def submit_order(self):
        if self.status == "Pending":
            self.status = "Submitted"
            for product in self.products:
                product.quantity -= 1
            self.user.orders.append(self)
            print("Order submitted successfully.")
        else:
            print("Order has already been submitted.")

# Creating instances
sweet_delights = SweetDelights()
user1 = User("JohnSmith", "password123")
product1 = Product("Croissant", 2.5, 10)
product2 = Product("Cupcake", 1.5, 20)

# Adding user and products to SweetDelights
sweet_delights.add_user(user1)
sweet_delights.add_product(product1)
sweet_delights.add_product(product2)

# Creating an order
sweet_delights.create_order(user1, [product1, product2])

# Generating sales report
sweet_delights.generate_sales_report()

# Showing inventory
sweet_delights.show_inventory()

# Viewing order history for the user
user1.view_order_history()

# Updating user profile
user1.update_profile("newpassword")

# Updating product
product1.update_product(3.0, 5)

# Submitting the order
sweet_delights.orders[0].submit_order()
# Out:
# Total Revenue: $4.0
# Croissant - Quantity: 10
# Cupcake - Quantity: 20
# No order history available.
# Profile updated for JohnSmith.
# Croissant updated - Price: $3.0, Quantity: 5
# Order submitted successfully.

# %%
# Group2:
# Team Members list:
# 1. Karima Kouadri Boudjelthia,
# 2. Micheal Mekoya,
# 3. Dim Huai

class SweetDelights:
    def __init__(self):
        self.users = []
        self.products = []
        self.orders = []

    def add_user(self, user):
        self.users.append(user)

    def add_product(self, product):
        self.products.append(product)

    def create_order(self, user, products):
        order = Order(user, products)
        self.orders.append(order)

    def generate_sales_report(self):
        total_revenue = sum(order.calculate_total() for order in self.orders)
        print(f"Total Revenue: ${total_revenue}")

    def show_inventory(self):
        for product in self.products:
            print(f"{product.name} - Quantity: {product.quantity}")

class User:
    def __init__(self, username, password):
        self.username = username
        self.password = password
        self.orders = []

    def view_order_history(self):
        if self.orders:
            print(f"Order History for {self.username}:")
            for order in self.orders:
                print(f"Order Status: {order.status}, Total Amount: ${order.calculate_total()}")
        else:
            print("No order history available.")

    def update_profile(self, new_password):
        self.password = new_password
        print(f"Profile updated for {self.username}.")

class Product:
    def __init__(self, name, price, quantity):
        self.name = name
        self.price = price
        self.quantity = quantity

    def update_product(self, new_price, new_quantity):
        self.price = new_price
        self.quantity = new_quantity
        print(f"{self.name} updated - Price: ${self.price}, Quantity: {self.quantity}")

class Order:
    def __init__(self, user, products):
        self.user = user
        self.products = products
        self.status = "Pending"

    def calculate_total(self):
        total = sum(product.price for product in self.products)
        return total

    def submit_order(self):
        if self.status == "Pending":
            self.status = "Submitted"
            for product in self.products:
                product.quantity -= 1
            self.user.orders.append(self)
            print("Order submitted successfully.")
        else:
            print("Order has already been submitted.")

# Creating instances
sweet_delights = SweetDelights()
user1 = User("JohnSmith", "password123")
product1 = Product("Croissant", 2.5, 10)
product2 = Product("Cupcake", 1.5, 20)

user2 = User("SarahBond", "password456")
product3 = Product("Freshly Baked Bread", 5.5, 15)
product4 = Product("Puffs and Pastries", 2.5, 25)

user3 = User("HollyPathaway", "password789")
product5 = Product("Biscuits and Cookies", 3.5, 10)
product6 = Product("Cakes", 1.5, 30)

user4 = User("DanielDo", "password101")
product7 = Product("Samosas", 0.75, 27)
product8 = Product("Muffins", 1.5, 25)

user5 = User("DavidBrown", "password121")
product9 = Product("Bread Rolls", 2.5, 7)
product10 = Product("Naan and Kulcha", 2.5, 35)

user6 = User("JessicaNice", "password131")
product11 = Product("Mawa Cake", 1.5, 50)
product12 = Product("Khari and Toast", 2.5, 25)

# Adding user and products to SweetDelights
sweet_delights.add_user(user1)
sweet_delights.add_product(product1)
sweet_delights.add_product(product2)

sweet_delights.add_user(user2)
sweet_delights.add_product(product3)
sweet_delights.add_product(product4)

sweet_delights.add_user(user3)
sweet_delights.add_product(product5)
sweet_delights.add_product(product6)

sweet_delights.add_user(user4)
sweet_delights.add_product(product7)
sweet_delights.add_product(product8)

sweet_delights.add_user(user5)
sweet_delights.add_product(product9)
sweet_delights.add_product(product10)

sweet_delights.add_user(user6)
sweet_delights.add_product(product11)
sweet_delights.add_product(product12)

# Creating an order
sweet_delights.create_order(user1, [product1, product2])
sweet_delights.create_order(user2, [product3, product4])
sweet_delights.create_order(user3, [product5, product6])
sweet_delights.create_order(user4, [product7, product8])
sweet_delights.create_order(user5, [product9, product10])
sweet_delights.create_order(user6, [product11, product12])

# Generating sales report
sweet_delights.generate_sales_report()

# Showing inventory
sweet_delights.show_inventory()

# Viewing order history for the user
user1.view_order_history()

# Updating user profile
user1.update_profile("newpassword")
user5.update_profile("newpassword")

# Updating product
product1.update_product(3.0, 5)
product6.update_product(4.0, 40)

# Submitting the order
sweet_delights.orders[0].submit_order()
# Out:
# Total Revenue: $28.25
# Croissant - Quantity: 10
# Cupcake - Quantity: 20
# Freshly Baked Bread - Quantity: 15
# Puffs and Pastries - Quantity: 25
# Biscuits and Cookies - Quantity: 10
# Cakes - Quantity: 30
# Samosas - Quantity: 27
# Muffins - Quantity: 25
# Bread Rolls - Quantity: 7
# Naan and Kulcha - Quantity: 35
# Mawa Cake - Quantity: 50
# Khari and Toast - Quantity: 25
# No order history available.
# Profile updated for JohnSmith.
# Profile updated for DavidBrown.
# Croissant updated - Price: $3.0, Quantity: 5
# Cakes updated - Price: $4.0, Quantity: 40
# Order submitted successfully.
